# %%
import pyspark as ps

# %%
import csv
import pandas as pd

# %%
file = "/Users/krishnasharma/Downloads/tree_cover_stats_2016.xlsx"
df_loss = pd.read_excel(file, sheet_name='Loss (2001-2016) by Country')
df_gain = pd.read_excel(file, sheet_name='Gain (2001-2012) by Country')

# %%
df_loss.rename(columns=df.iloc[0])
df_loss.drop(df.index[0])

df_gain.rename(columns=df.iloc[0])
df_gain.drop(df.index[0])
# Out:
#                 All areas are in hectares      TREE COVER GAIN
# 0                                 Country  (>50% CANOPY COVER)
# 1                             Afghanistan               303.87
# 2                   Akrotiri and Dhekelia              3.30451
# 3                                 Albania              7355.14
# 4                                 Algeria              32539.5
# 5                          American Samoa                    0
# 6                                 Andorra              17.9006
# 7                                  Angola              63797.3
# 8                                Anguilla              29.1222
# 9                              Antarctica                    0
# 10                    Antigua and Barbuda              248.593
# 11                              Argentina               643049
# 12                                Armenia              1278.23
# 13                                  Aruba               1.0522
# ...
